# %%
import numpy as np
import pandas as pd
from pandas import DataFrame,Series

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep=r"\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']


boston_df = pd.DataFrame(data, columns=column_names[:-1])
boston_df['MEDV'] = target

boston_df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
plt.hist(boston_df['MEDV'],bins=50)
plt.xlabel('Prices in $1000s')
plt.ylabel('No of Houses')
# Out:
# Text(0, 0.5, 'No of Houses')

# %%
plt.scatter(boston_df['RM'],boston_df['MEDV'])
plt.ylabel('Prices in $1000s')
plt.xlabel('No of rooms')
# Out:
# Text(0.5, 0, 'No of rooms')

# %%
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
boston_df['Price'] = boston_df['MEDV']
boston_df = boston_df.drop(columns=['MEDV'])
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
sns.lmplot(x='RM',y='Price',data=boston_df)

# %%
from IPython.display import Image
url = 'http://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Linear_least_squares_example2.svg/220px-Linear_least_squares_example2.svg.png'
Image(url)

# %%
X= boston_df.RM
Y=boston_df.Price
X=np.hstack(boston_df.RM)
X=np.array([[value,1] for value in X])
m,b = np.linalg.lstsq(X,Y)[0]
plt.plot(boston_df.RM,boston_df.Price,'o')
x=boston_df.RM
plt.plot(x,m*x+b,'r',label='Heading')
plt.show()
# Out:
# C:\Users\abin.k\AppData\Local\Temp\ipykernel_19620\2098423397.py:5: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m,b = np.linalg.lstsq(X,Y)[0]

# %%
result = np.linalg.lstsq(X,Y)
error_total = result[1]

rmse = np.sqrt(error_total/len(X))

print ("The root mean squared error was %.2f" %rmse)
# Out:
# The root mean squared error was 6.60
# C:\Users\abin.k\AppData\Local\Temp\ipykernel_19620\3890660574.py:1: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   result = np.linalg.lstsq(X,Y)
# C:\Users\abin.k\AppData\Local\Temp\ipykernel_19620\3890660574.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print ("The root mean squared error was %.2f" %rmse)

# %%
import sklearn
from sklearn.linear_model import LinearRegression

# %%
lreg = LinearRegression()

# %%
X_multi = boston_df.drop('Price',axis=1)
Y_target = boston_df.Price

# %%
lreg.fit(X_multi,Y_target)
# Out:
# LinearRegression()

# %%
print ("The estimated intercept coefficient is %.2f " %lreg.intercept_)
print ('The number of coefficient used was %d' %len(lreg.coef_))
# Out:
# The estimated intercept coefficient is 36.46
# The number of coefficient used was 13

# %%
coeff_df = DataFrame(boston_df.columns)
coeff_df.columns = ['Features']

coeff_df['Coefficient Estimate'] = Series(lreg.coef_)
coeff_df
# Out:
#    Features  Coefficient Estimate
# 0      CRIM             -0.108011
# 1        ZN              0.046420
# 2     INDUS              0.020559
# 3      CHAS              2.686734
# 4       NOX            -17.766611
# 5        RM              3.809865
# 6       AGE              0.000692
# 7       DIS             -1.475567
# 8       RAD              0.306049
# 9       TAX             -0.012335
# 10  PTRATIO             -0.952747
# 11        B              0.009312
# 12    LSTAT             -0.524758
# 13    Price                   NaN

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, boston_df.Price)

# %%
lreg = LinearRegression()
lreg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
pred_train = lreg.predict(X_train)
pred_test  = lreg.predict(X_test)

# %%
print("Fit a model X_train, and calculate MSE with Y_train: %.2f"  % np.mean((Y_train - pred_train) ** 2))
    
print("Fit a model X_train, and calculate MSE with X_test and Y_test: %.2f"  %np.mean((Y_test - pred_test) ** 2))
# Out:
# Fit a model X_train, and calculate MSE with Y_train: 43.60
# Fit a model X_train, and calculate MSE with X_test and Y_test: 43.93

# %%
train = plt.scatter(pred_train,(Y_train-pred_train),c='b',alpha=0.5)
test = plt.scatter(pred_test,(Y_test-pred_test),c='r',alpha=0.5)
plt.hlines(y=0,xmin=-10,xmax=50)
plt.legend((train,test),('Training','Test'),loc='lower left')
plt.title('Residual Plots')
# Out:
# Text(0.5, 1.0, 'Residual Plots')

# %%
sns.residplot(x='RM', y='Price', data = boston_df)
# Out:
# <Axes: xlabel='RM', ylabel='Price'>
